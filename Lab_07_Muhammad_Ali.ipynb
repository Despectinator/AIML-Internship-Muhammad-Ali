# %% [markdown]
# <a href="https://colab.research.google.com/github/Despectinator/AIML-Internship-Muhammad-Ali/blob/main/Lab_07_Muhammad_Ali.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 7 (Week 2 — Lab 2): Regression Models
#
# Welcome to Lab 7! In this lab, you will build your first predictive models: **Regression Models**, which predict continuous numeric values (such as prices, scores, or measurements) rather than categories.
#
# **For detailed theory on Linear Regression, Cost Functions (MSE), Multiple Regression, Polynomial Regression, and Evaluation Metrics (MSE, RMSE, R²), see the Lab 7 PDF and Learning Resources.**
#
# This notebook focuses on the practical, hands-on workflow using **scikit-learn** and **Pandas**.

# %% [markdown]
# ---
# ## Dataset Overview: California Housing Dataset
#
# In this lab, we will use the **California Housing Dataset** (available directly in `scikit-learn`).
#
# - **Target variable (`y`)**: `MedHouseVal` — Median house value for California districts (expressed in hundreds of thousands of dollars, e.g., 2.0 = $200,000).
# - **Features (`X`)**:
#   1. `MedInc`: Median income in block group
#   2. `HouseAge`: Median house age in block group
#   3. `AveRooms`: Average number of rooms per household
#   4. `AveBedrms`: Average number of bedrooms per household
#   5. `Population`: Block group population
#   6. `AveOccup`: Average number of household members
#   7. `Latitude`: Block group latitude
#   8. `Longitude`: Block group longitude

# %% [markdown]
# ## Example 1: Loading & Exploring the Dataset
#
# First, let's load the dataset, create a Pandas DataFrame, and inspect the target variable and features.

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd
import numpy as np

# Load California Housing dataset
housing = fetch_california_housing(as_frame=True)
df = housing.frame

print("Dataset shape:", df.shape)
print("\nFirst 5 rows:")
print(df.head())
# Out:
# Dataset shape: (20640, 9)
#
# First 5 rows:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %% [markdown]
# ## Example 2: Simple Linear Regression & Model Evaluation
#
# Let's predict house prices (`MedHouseVal`) using just one feature: **Median Income (`MedInc`)**.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Select single feature and target
X_simple = df[['MedInc']]
y = df['MedHouseVal']

# Train-test split (80-20)
X_train, X_test, y_train, y_test = train_test_split(X_simple, y, test_size=0.2, random_state=42)

# Train model
model_simple = LinearRegression()
model_simple.fit(X_train, y_train)

# Predictions
y_pred_simple = model_simple.predict(X_test)

# Evaluation
mse = mean_squared_error(y_test, y_pred_simple)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred_simple)

print(f"Slope (Coefficient): {model_simple.coef_[0]:.4f}")
print(f"Intercept: {model_simple.intercept_:.4f}")
print(f"MSE: {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"R2 Score: {r2:.4f}")
# Out:
# Slope (Coefficient): 0.4193
# Intercept: 0.4446
# MSE: 0.7091
# RMSE: 0.8421
# R2 Score: 0.4589

# %% [markdown]
# ## Example 3: Multiple Linear Regression
#
# Now, let's use multiple features (`MedInc`, `HouseAge`, `AveRooms`) to improve our prediction model.

# %%
# Select multiple features
features = ['MedInc', 'HouseAge', 'AveRooms']
X_multi = df[features]

X_train_m, X_test_m, y_train_m, y_test_m = train_test_split(X_multi, y, test_size=0.2, random_state=42)

# Train multiple linear regression
model_multi = LinearRegression()
model_multi.fit(X_train_m, y_train_m)

y_pred_multi = model_multi.predict(X_test_m)

# Evaluate
rmse_multi = np.sqrt(mean_squared_error(y_test_m, y_pred_multi))
r2_multi = r2_score(y_test_m, y_pred_multi)

print(f"Multiple Regression RMSE: {rmse_multi:.4f}")
print(f"Multiple Regression R2 Score: {r2_multi:.4f}")
print("\nFeature Coefficients:")
for feature, coef in zip(features, model_multi.coef_):
    print(f"{feature}: {coef:.4f}")
# Out:
# Multiple Regression RMSE: 0.8117
# Multiple Regression R2 Score: 0.4972
#
# Feature Coefficients:
# MedInc: 0.4448
# HouseAge: 0.0168
# AveRooms: -0.0281

# %% [markdown]
# ## Practice Exercise 1: Predicting with a Custom Inputs
#
# **Exercise:** Use the trained `model_simple` from Example 2 to predict the house value (`MedHouseVal`) for a neighborhood with a median income (`MedInc`) of **5.0** (which represents $50,000).

# %%
### YOUR CODE HERE ###
new_income = pd.DataFrame({'MedInc': [5.0]})
predicted_value = model_simple.predict(new_income)

print(f"Predicted Median House Value for MedInc=5.0: {predicted_value[0]:.4f}")
print(f"That is approximately ${predicted_value[0]*100000:.2f}")
### END ###
# Out:
# Predicted Median House Value for MedInc=5.0: 2.5413
# That is approximately $254128.98

# %% [markdown]
# ## Practice Exercise 2: Polynomial Regression
#
# **Exercise:** Perform Polynomial Regression of **degree=2** on the single feature `MedInc`. Train the model and calculate the R² Score on the test set.

# %%
from sklearn.preprocessing import PolynomialFeatures

### YOUR CODE HERE ###
from sklearn.preprocessing import PolynomialFeatures

# 1. Create PolynomialFeatures with degree 2
poly = PolynomialFeatures(degree=2)

# 2. Transform X_train and X_test (using the single-feature MedInc split from Example 2)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# 3. Fit LinearRegression on transformed data
model_poly = LinearRegression()
model_poly.fit(X_train_poly, y_train)

# 4. Calculate and print R2 Score
y_pred_poly = model_poly.predict(X_test_poly)
r2_poly = r2_score(y_test, y_pred_poly)

print(f"Polynomial Regression (degree=2) R2 Score: {r2_poly:.4f}")

### END ###
# Out:
# Polynomial Regression (degree=2) R2 Score: 0.4633

# %% [markdown]
# ## Lab Tasks
#
# Complete the following tasks in this notebook below this cell.
#
# 1. **Full Feature Regression**: Train a Linear Regression model using ALL 8 features from the California Housing dataset. Perform an 80-20 train-test split. Print the RMSE and R² score.
# 2. **Coefficient Analysis**: Display all feature names alongside their learned coefficients for the model built in Task 1. Identify which feature has the strongest positive impact on house prices.
# 3. **Comparison**: Compare the R² score of the simple regression model (Example 2) with the full feature model (Task 1). In a Markdown cell, write 2-3 sentences explaining why including more features improved or changed the performance.
# 4. **Reflection**: Write 2-3 sentences on what you learned in this lab and how evaluation metrics (RMSE vs R²) help us understand model performance.

# %%
# Task 1

X_full = df.drop('MedHouseVal', axis=1)
y_full = df['MedHouseVal']

# 80-20 train-test split
X_train_f, X_test_f, y_train_f, y_test_f = train_test_split(
    X_full, y_full, test_size=0.2, random_state=42
)

# Train Linear Regression on all features
model_full = LinearRegression()
model_full.fit(X_train_f, y_train_f)

# Predictions
y_pred_full = model_full.predict(X_test_f)

# Evaluation
rmse_full = np.sqrt(mean_squared_error(y_test_f, y_pred_full))
r2_full = r2_score(y_test_f, y_pred_full)

print(f"Full Feature Regression RMSE: {rmse_full:.4f}")
print(f"Full Feature Regression R2 Score: {r2_full:.4f}")
# Out:
# Full Feature Regression RMSE: 0.7456
# Full Feature Regression R2 Score: 0.5758

# %%
# Task 2

coef_df = pd.DataFrame({
    'Feature': X_full.columns,
    'Coefficient': model_full.coef_
}).sort_values(by='Coefficient', ascending=False).reset_index(drop=True)

print("Feature Coefficients (sorted, strongest positive first):")
print(coef_df)

strongest_positive = coef_df.iloc[0]
print(f"\nFeature with strongest POSITIVE impact on house price: "
      f"{strongest_positive['Feature']} (coefficient = {strongest_positive['Coefficient']:.4f})")

strongest_negative = coef_df.iloc[-1]
print(f"Feature with strongest NEGATIVE impact on house price: "
      f"{strongest_negative['Feature']} (coefficient = {strongest_negative['Coefficient']:.4f})")
# Out:
# Feature Coefficients (sorted, strongest positive first):
#       Feature  Coefficient
# 0   AveBedrms     0.783145
# 1      MedInc     0.448675
# 2    HouseAge     0.009724
# 3  Population    -0.000002
# 4    AveOccup    -0.003526
# 5    AveRooms    -0.123323
# 6    Latitude    -0.419792
# 7   Longitude    -0.433708
#
# Feature with strongest POSITIVE impact on house price: AveBedrms (coefficient = 0.7831)
# Feature with strongest NEGATIVE impact on house price: Longitude (coefficient = -0.4337)

# %% [markdown]
# _Write your Task 3 response here._
#
# Task 3: Comparison
#
# The simple regression model (using only MedInc) achieved a lower R² score than the full feature model that used all 8 predictors. Including more features improved performance because house prices depend on more than just income — factors like house age, room counts, population density, and geographic location (latitude/longitude) all carry additional information that helps explain variation in MedHouseVal. Since each new feature can capture a different part of the underlying pattern, the multiple regression model reduces the leftover error that MedInc alone could not account for, raising R² and lowering RMSE.

# %% [markdown]
# _Write your Task 4 reflection here._
#
# ### Task 4: Reflection
#
# In this lab, I learned how to build and evaluate regression models using scikit-learn, moving from a simple one-feature linear regression to multiple regression with several features, and even a polynomial regression to capture non-linear relationships. I also learned how to interpret model coefficients to understand which features drive predictions. RMSE and R² help evaluate a model in different but complementary ways: RMSE tells us the typical size of prediction error in the same units as the target (making it easy to judge whether errors are practically acceptable), while R² tells us what proportion of the variance in the target the model actually explains, giving a sense of overall model quality independent of the target's scale.
